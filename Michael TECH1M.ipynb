# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.simplefilter("ignore")
# %matplotlib inline

# %%
df = pd.read_csv("train (3).csv")
df1 = pd.read_csv("store.csv")

# %%
df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
df.shape
# Out:
# (1017209, 9)

# %%
df1.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
df1.shape
# Out:
# (1115, 10)

# %%
main_df = df.merge(df1, on =["Store"], how = "inner")

# %%
main_df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            1          4  2015-07-30   5020        546     1      1
# 2            1          3  2015-07-29   4782        523     1      1
# 3            1          2  2015-07-28   5011        560     1      1
# 4            1          1  2015-07-27   6102        612     1      1
# 5            1          7  2015-07-26      0          0     0      0
# 6            1          6  2015-07-25   4364        500     1      0
# 7            1          5  2015-07-24   3706        459     1      0
# 8            1          4  2015-07-23   3769        503     1      0
# 9            1          3  2015-07-22   3464        463     1      0
# 10           1          2  2015-07-21   3558        469     1      0
# 11           1          1  2015-07-20   4395        526     1      0
# 12           1          7  2015-07-19      0          0     0      0
# ...

# %%
main_df.shape
# Out:
# (1017209, 18)

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
# Store                        1017209 non-null int64
# DayOfWeek                    1017209 non-null int64
# Date                         1017209 non-null object
# Sales                        1017209 non-null int64
# Customers                    1017209 non-null int64
# Open                         1017209 non-null int64
# Promo                        1017209 non-null int64
# StateHoliday                 1017209 non-null object
# SchoolHoliday                1017209 non-null int64
# StoreType                    1017209 non-null object
# Assortment                   1017209 non-null object
# CompetitionDistance          1014567 non-null float64
# CompetitionOpenSinceMonth    693861 non-null float64
# CompetitionOpenSinceYear     693861 non-null float64
# Promo2                       1017209 non-null int64
# Promo2SinceWeek              509178 non-null float64
# ...

# %%
main_df.duplicated().sum()
# Out:
# 0

# %%
main_df.isnull().sum()
# Out:
# Store                             0
# DayOfWeek                         0
# Date                              0
# Sales                             0
# Customers                         0
# Open                              0
# Promo                             0
# StateHoliday                      0
# SchoolHoliday                     0
# StoreType                         0
# Assortment                        0
# CompetitionDistance            2642
# CompetitionOpenSinceMonth    323348
# CompetitionOpenSinceYear     323348
# Promo2                            0
# Promo2SinceWeek              508031
# Promo2SinceYear              508031
# PromoInterval                508031
# dtype: int64

# %%
main_df.isnull().sum()/len(main_df)*100
# Out:
# Store                         0.000000
# DayOfWeek                     0.000000
# Date                          0.000000
# Sales                         0.000000
# Customers                     0.000000
# Open                          0.000000
# Promo                         0.000000
# StateHoliday                  0.000000
# SchoolHoliday                 0.000000
# StoreType                     0.000000
# Assortment                    0.000000
# CompetitionDistance           0.259730
# CompetitionOpenSinceMonth    31.787764
# CompetitionOpenSinceYear     31.787764
# Promo2                        0.000000
# Promo2SinceWeek              49.943620
# Promo2SinceYear              49.943620
# PromoInterval                49.943620
# dtype: float64

# %%
final_df =main_df[["Store",
                   "DayOfWeek",
                   "Date",
                   "Sales",
                   "Customers",
                   "Open",
                   "Promo",
                   "StateHoliday",
                   "SchoolHoliday",
                   "StoreType",
                   "Assortment"]]

# %%
final_df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      1          4  2015-07-30   5020        546     1      1            0
# 2      1          3  2015-07-29   4782        523     1      1            0
# 3      1          2  2015-07-28   5011        560     1      1            0
# 4      1          1  2015-07-27   6102        612     1      1            0
#
#    SchoolHoliday StoreType Assortment
# 0              1         c          a
# 1              1         c          a
# 2              1         c          a
# 3              1         c          a
# 4              1         c          a

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 11 columns):
# Store            1017209 non-null int64
# DayOfWeek        1017209 non-null int64
# Date             1017209 non-null object
# Sales            1017209 non-null int64
# Customers        1017209 non-null int64
# Open             1017209 non-null int64
# Promo            1017209 non-null int64
# StateHoliday     1017209 non-null object
# SchoolHoliday    1017209 non-null int64
# StoreType        1017209 non-null object
# Assortment       1017209 non-null object
# dtypes: int64(7), object(4)
# memory usage: 133.1+ MB

# %% [markdown]
# #### observation
# there are some columns with wrong datatype

# %%
# change some columns that are stored as integer to categorical datatype
final_df['Open'] = final_df['Open'].astype('category')
final_df['Promo'] = final_df['Promo'].astype('category')
final_df['StateHoliday'] = final_df['StateHoliday'].astype('category')
final_df['SchoolHoliday'] = final_df['SchoolHoliday'].astype('category')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 11 columns):
# Store            1017209 non-null int64
# DayOfWeek        1017209 non-null int64
# Date             1017209 non-null object
# Sales            1017209 non-null int64
# Customers        1017209 non-null int64
# Open             1017209 non-null category
# Promo            1017209 non-null category
# StateHoliday     1017209 non-null category
# SchoolHoliday    1017209 non-null category
# StoreType        1017209 non-null object
# Assortment       1017209 non-null object
# dtypes: category(4), int64(4), object(3)
# memory usage: 106.0+ MB

# %%
final_df.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03

# %% [markdown]
# #### observation;
# from using .describe(),its revealed the numeric data doesn't have outlier

# %%
plt.plot(final_df["Customers"])
plt.title("distribution of store");

# %%
final_df["Sales"].sum()
# Out:
# 5873180623

# %%
final_df["Sales"].mean()
# Out:
# 5773.818972305593

# %%
final_df["Promo"].value_counts()
# Out:
# 0    629129
# 1    388080
# Name: Promo, dtype: int64

# %%
final_df['Date'] = pd.to_datetime(final_df["Date"],infer_datetime_format = True)

# %%
final_df['Year']= final_df["Date"].dt.year
final_df['Month']= final_df["Date"].dt.month
final_df['Day']= final_df["Date"].dt.day

# %%
final_df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers Open Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555    1     1            0
# 1      1          4 2015-07-30   5020        546    1     1            0
# 2      1          3 2015-07-29   4782        523    1     1            0
# 3      1          2 2015-07-28   5011        560    1     1            0
# 4      1          1 2015-07-27   6102        612    1     1            0
#
#   SchoolHoliday StoreType Assortment  Year  Month  Day
# 0             1         c          a  2015      7   31
# 1             1         c          a  2015      7   30
# 2             1         c          a  2015      7   29
# 3             1         c          a  2015      7   28
# 4             1         c          a  2015      7   27

# %%
final_df.pivot_table(index="StoreType", values = "Sales", aggfunc = "sum")
# Out:
#                 Sales
# StoreType
# a          3165334859
# b           159231395
# c           783221426
# d          1765392943

# %% [markdown]
# #### Observation
# The most selling and crowded StoreType is a

# %%
final_df.pivot_table(index="StoreType", values = ["Customers", "Sales"], aggfunc = "sum")
# Out:
#            Customers       Sales
# StoreType
# a          363541434  3165334859
# b           31465621   159231395
# c           92129705   783221426
# d          156904995  1765392943

# %% [markdown]
# #### Observation
# We can see that StoreType A has higher amounts of both total customers and sales

# %%
df_plot = final_df.pivot_table(index="StoreType", values = ["Customers", "Sales"], aggfunc = "sum")

# %%
df_plot.plot(kind = 'bar', linewidth=2.0)

# %%
final_df.pivot_table(index="StoreType", values = "Promo", aggfunc = "count")
# Out:
#             Promo
# StoreType
# a          551627
# b           15830
# c          136840
# d          312912

# %%
final_df.pivot_table(index="Promo", values = "Sales", aggfunc = "sum")
# Out:
#             Sales
# Promo
# 0      2771974337
# 1      3101206286

# %%
df_sales = final_df.pivot_table(index="Promo", values = "Sales", aggfunc = "sum")
df_sales.plot(kind='bar')

# %%
final_df.pivot_table(index="Promo", values = "Customers", aggfunc = "sum")
# Out:
#        Customers
# Promo
# 0      325777807
# 1      318263948

# %%
df_customers = final_df.pivot_table(index="Promo", values = "Customers", aggfunc = "sum")
df_customers.plot(kind = 'bar')

# %%
final_df.pivot_table(index="SchoolHoliday", values = "Customers", aggfunc = "sum")
# Out:
#                Customers
# SchoolHoliday
# 0              516035131
# 1              128006624

# %%
final_df.pivot_table(index="SchoolHoliday", values = "Sales", aggfunc = "sum")
# Out:
#                     Sales
# SchoolHoliday
# 0              4696260531
# 1              1176920092

# %%
final_df.pivot_table(index="Promo", values = ["Sales", "Customers"], aggfunc = "sum")
# Out:
#        Customers       Sales
# Promo
# 0      325777807  2771974337
# 1      318263948  3101206286

# %% [markdown]
# #### Observation
# It is observed that Promo has a huge impact on Sales but no impact on the column

# %%
final_df.pivot_table(index= ["Year", "Promo"], values = ["Sales", "Customers"], aggfunc = "sum")
# Out:
#             Customers       Sales
# Year Promo
# 2013 0      132503934  1117639183
#      1      123500491  1185236901
# 2014 0      121234075  1023596760
#      1      119254896  1157208136
# 2015 0       72039798   630738394
#      1       75508561   758761249

# %% [markdown]
# #### Observation
# From the table above it is observed that Promo has no effect in the year 2014 and 2015 but there is effect in the year 2015 on Customers
# While there was an huge impact of promo from the year 2013 to 2015 on Sales

# %%
final_df.pivot_table(index="StoreType", columns= "Promo", values = ["Sales", "Customers"], aggfunc = "sum")
# Out:
#            Customers                  Sales
# Promo              0          1           0           1
# StoreType
# a          180276608  183264826  1466971549  1698363310
# b           18685985   12779636    92061910    67169485
# c           47222206   44907499   375186657   408034769
# d           79593008   77311987   837754221   927638722
